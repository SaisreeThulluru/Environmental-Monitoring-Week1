# %% [markdown]
# # 🌍 Environmental Monitoring and Pollution Control - Week 1
# This notebook contains basic data analysis and visualization for pollution monitoring.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#          Date  PM2.5  NO2    CO
# 0  01-01-2023    121   36  0.65
# 1  02-01-2023     64   58  1.58
# 2  03-01-2023     99   70  0.72
# 3  04-01-2023    114   37  0.82
# 4  05-01-2023    101   33  1.94

# %%
df.describe()
# Out:
#             PM2.5        NO2         CO
# count   30.000000  30.000000  30.000000
# mean   108.566667  48.900000   1.186333
# std     23.930479  16.270027   0.404803
# min     64.000000  22.000000   0.560000
# 25%     93.750000  34.500000   0.822500
# 50%    109.500000  48.500000   1.220000
# 75%    124.750000  61.500000   1.467500
# max    144.000000  77.000000   1.940000

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['PM2.5'], marker='o')
plt.xticks(rotation=45)
plt.title('PM2.5 Levels Over Time')
plt.xlabel('Date')
plt.ylabel('PM2.5 (µg/m³)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['NO2'], color='orange', marker='s')
plt.xticks(rotation=45)
plt.title('NO₂ Levels Over Time')
plt.xlabel('Date')
plt.ylabel('NO₂ (ppb)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['CO'], color='green', marker='^')
plt.xticks(rotation=45)
plt.title('CO Levels Over Time')
plt.xlabel('Date')
plt.ylabel('CO (mg/m³)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✅ Conclusion
# - Pollution levels fluctuate daily.
# - PM2.5 levels are relatively higher compared to NO₂ and CO.
# - Further steps can include predicting pollution levels using ML models.
